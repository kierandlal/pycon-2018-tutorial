# %%
print ('hello world')
# Out:
# <pre class="jp-command-status-text">Command execution completed</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# hello world

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
ri = pd.read_csv('police.csv')
ted = pd.read_csv('ted.csv')
ri.driver_age.plot()
# Out:
# <pre class="jp-command-status-text">Command took 1.23 seconds -- by clemens@databricks.com at 04/20/2020, 08:51:04 PM UTC on my_jupyter_cluster</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
